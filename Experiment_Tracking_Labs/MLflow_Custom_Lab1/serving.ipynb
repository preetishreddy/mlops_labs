# %%
model_path = "mlruns/0/<RUN_ID>/artifacts/model"
print("Replace <RUN_ID> with actual run ID from MLflow UI")

# %%
print("Run this in terminal:")
print(f"mlflow models serve -m {model_path} -p 5002 --no-conda")

# %%
import requests
import pandas as pd
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)
X = housing.data

sample = {
    "columns": X.columns.tolist(),
    "data": [X.iloc[0].tolist()]
}

response = requests.post('http://127.0.0.1:5002/invocations', json=sample)
response.json()
