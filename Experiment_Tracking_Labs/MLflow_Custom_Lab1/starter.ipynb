# %%
# !pip install mlflow scikit-learn numpy pandas seaborn matplotlib

# %%
print("""
MLflow Experiment Tracking

This notebook explains:
1. What MLflow experiments and runs are
2. How MLflow stores metrics, params, artifacts
3. How to launch MLflow UI
""")

# %%
print("To start MLflow UI, run in terminal:\n\n  mlflow ui --port 5001")

# %%
import os
print('mlruns exists:', os.path.exists('mlruns'))
